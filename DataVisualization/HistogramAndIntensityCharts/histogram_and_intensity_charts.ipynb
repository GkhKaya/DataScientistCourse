# %%
import seaborn as sns
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.displot(df.price, kde = False);
# Out:
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df.price, kde = False,bins=10);
# Out:
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df.price);
# Out:
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df.price,hist=False);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.displot(df.price,hist=False)
#
# File ~/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/distributions.py:2210, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2207 if p.univariate:
#    2209     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2210     p.plot_univariate_histogram(**hist_kws)
#    2212 else:
#    2214     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# File ~/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/distributions.py:575, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     570 if element == "bars":
#     571
#     572     # Use matplotlib bar plotting
#     574     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 575     artists = plot_func(
#     576         hist["edges"],
#     577         hist["heights"] - bottom,
#     578         hist["widths"],
#     579         bottom,
#     580         align="edge",
#     581         **artist_kws,
#     582     )
#     584     for bar in artists:
#     585         if self.data_variable == "x":
#
# File ~/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2480, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2471 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2472     r = mpatches.Rectangle(
#    2473         xy=(l, b), width=w, height=h,
#    2474         facecolor=c,
#    (...)
#    2478         hatch=htch,
#    2479         )
# -> 2480     r._internal_update(kwargs)
#    2481     r.get_path()._interpolation_steps = 100
#    2482     if orientation == 'vertical':
#
# File ~/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'hist'

# %%
sns.kdeplot(df.price,shade=True)
# Out:
# /var/folders/tf/9dmsl16n27l53t38b0gggbp80000gn/T/ipykernel_5528/1834324341.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.price,shade=True)
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ## Histogram and intensity crosses

# %%
(sns
.FacetGrid(df,
              hue="cut",
              height=5,
              xlim= (0,10000))
.map(sns.kdeplot,"price",shade=True)
.add_legend()
 );
# Out:
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="cut",y="price",hue="color",kind="point",data=df);
# Out:
# /Users/gkhkaya/anaconda3/envs/DataScientistCourse/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
